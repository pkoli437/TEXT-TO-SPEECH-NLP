# %% [markdown]
# # METHOD 1

# %%
#INSTALL THIS MODULE
pip install pyttsx3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\pruthvi koli\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\pruthvi koli\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\pruthvi koli\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\pruthvi koli\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\pruthvi koli\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\pruthvi koli\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\pruthvi koli\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\pruthvi koli\anaconda3\lib\site-packages)

# %%
#IMPORT LIBRARRY REQUIRED
import pyttsx3

# %%
#INITIATE THE 'INIT' FUNCTION IN ORDER TO GET AN ENGINE INSTANCE
Jarvis = pyttsx3.init()

# %%
Jarvis.say("Oh my God I can't believe I create this model in less than 5 minutes")

# %%
#AFTER RUNNING THIS VOICE WILL BE PROCESSED AND WE CAN HEAR THE TEXTED VOICE
Jarvis.runAndWait()

# %% [markdown]
# # METHOD 2

# %%
pip install gTTS
# Out:
# ...
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\pruthvi koli\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\pruthvi koli\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\pruthvi koli\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\pruthvi koli\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\pruthvi koli\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\pruthvi koli\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\pruthvi koli\anaconda3\lib\site-packages)

# %%
##IMPORT LIBRARRY REQUIRED
from gtts import gTTS

# %%
from IPython.display import Audio

# %%
#PASS THE TEXT IN ENGINE 
speech=gTTS('Congratulations you have created text to speech model in just 5 minutes')

# %%
speech.save('1.wave')

# %%
sound_file='1.wave'

# %%
#RUN THIS CODE AND HEAR THE VOICE
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
